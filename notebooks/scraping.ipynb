# %%
# Importa las librerias necesarias
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
from dotenv import load_dotenv

# %%
# Carga las variables de entorno
load_dotenv()

# Lee las variables de entorno
email = os.getenv('EMAIL')
password = os.getenv('PASSWORD')

# %%
# Inicializa el navegador
driver = webdriver.Chrome()

# Abre la página de inicio de sesión
driver.get('https://www.easybroker.com/mx/account/authentication/new')

# %%
# Espera a que se cargue la página
time.sleep(2)

# Hace clic en el botón de iniciar sesión con email
boton_email = driver.find_element(By.XPATH, '//a[@data-email-button]')
boton_email.click()

# %%
# Espera a que se muestre el formulario
time.sleep(2)

# Ingresa el email
campo_email = driver.find_element(By.XPATH, '//input[@id="authentication_email"]')
campo_email.send_keys(email) # Reemplaza 'email' con tu email

# %%
# Hace clic en continuar
boton_continuar = driver.find_element(By.XPATH, '//input[@value="Continuar"]')
boton_continuar.click()

# %%
# Espera a que se muestre el siguiente formulario
time.sleep(2)

# Ingresa la contraseña
campo_password = driver.find_element(By.XPATH, '//input[@id="session_password"]')
campo_password.send_keys(password)  # Reemplaza 'password' con tu contraseña

# %%
# Hace clic en iniciar sesión
boton_iniciar_sesion = driver.find_element(By.XPATH, '//input[@value="Iniciar sesión"]')
boton_iniciar_sesion.click()

# %%
# Inicializa listas para almacenar los datos
nombres = []
ciudades = []
telefonos = []
sitios_web = []

# %%
# Itera sobre las páginas
for i in range(1, 342):  # Ajusta el rango según sea necesario
    # Navega a la página
    driver.get(f'https://www.easybroker.com/agent/agencies/search?page={i}&reset_page=true')

    # Obtiene el HTML de la página
    html = driver.page_source

    # Analiza el HTML
    soup = BeautifulSoup(html, 'html.parser')

    # Encuentra los elementos necesarios
    elements = soup.find_all('div', class_='col-md-4')

    # Itera sobre los elementos y extrae los datos
    for element in elements:
        nombre = element.find('h6', class_="organization-title m-0").text.strip()
        ciudad = element.find('p', class_="m-0").text.strip()
        telefono_element = element.find('a', href=lambda href: href and "tel:" in href)
        telefono = telefono_element.text.strip() if telefono_element else None
        enlace = element.find('a', target="_blank")
        sitio_web = enlace.get('href') if enlace else None
        
        # Agrega los datos a las listas correspondientes
        nombres.append(nombre)
        ciudades.append(ciudad)
        telefonos.append(telefono)
        sitios_web.append(sitio_web)

# %%
# Crea un DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Ciudad': ciudades,
    'Telefono': telefonos,
    'Sitio web': sitios_web,
})
df
# Out:
#                                      Nombre  \
# 0     Air Network de Asesores Inmobiliarios
# 1                            Inmuebles Hahn
# 2                             VIA INMUEBLES
# 3                             Pulppo Mexico
# 4             M&M Consultores Inmobiliarios
# ...                                     ...
# 6122                                 Altius
# 6123         Inmobiliaria de Patricia Palos
# 6124            Trávitat Grupo Inmobiliario
# 6125         Inmobiliaria de Miguel MARRERO
# 6126      Inmobiliaria de Rolo Inmobiliaria
#
#                                   Ciudad       Telefono  \
# 0       Ciudad de México, Álvaro Obregón       00000000
# 1           Ciudad de México, Cuauhtémoc     5555467531
# 2     Nuevo León, San Pedro Garza García  (81)8378-6238
# 3       Ciudad de México, Miguel Hidalgo  +525510163803
# 4       Ciudad de México, Miguel Hidalgo     5552573737
# ...                                  ...            ...
# 6122    Ciudad de México, Miguel Hidalgo     5526792674
# 6123         Baja California Sur, La Paz  +526122340454
# 6124                Jalisco, Guadalajara     3331058999
# 6125                     Yucatán, Mérida   +13026903002
# 6126                                      +529982141871
#
#                                               Sitio web
# 0     https://network-de-asesores-inmobiliarios.easy...
# 1                        https://www.inmuebleshahn.com/
# 2                                                  None
# 3                                                  None
# 4     https://m-y-m-consultores-inmobiliarios.easybr...
# ...                                                 ...
# 6122              https://altiusgroupmx.easybroker.com/
# 6123                                               None
# 6124                                               None
# 6125                                               None
# 6126                                               None
#
# [6127 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6127 entries, 0 to 6126
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     6127 non-null   object
#  1   Ciudad     5582 non-null   object
#  2   Telefono   6049 non-null   object
#  3   Sitio web  2781 non-null   object
# dtypes: object(4)
# memory usage: 191.6+ KB

# %%
# Reemplaza las filas vacías con None 
df['Ciudad'] = df['Ciudad'].replace("", None)

# %%
# Guarda el DataFrame en un archivo CSV
df.to_csv('data/raw/datos.csv', index=False)

# %%
df=pd.read_csv('../../data/raw/datos.csv')
df
# Out:
#                                      Nombre  \
# 0     Air Network de Asesores Inmobiliarios
# 1                            Inmuebles Hahn
# 2                             VIA INMUEBLES
# 3                             Pulppo Mexico
# 4             M&M Consultores Inmobiliarios
# ...                                     ...
# 6122                                 Altius
# 6123         Inmobiliaria de Patricia Palos
# 6124            Trávitat Grupo Inmobiliario
# 6125         Inmobiliaria de Miguel MARRERO
# 6126      Inmobiliaria de Rolo Inmobiliaria
#
#                                   Ciudad       Telefono  \
# 0       Ciudad de México, Álvaro Obregón       00000000
# 1           Ciudad de México, Cuauhtémoc     5555467531
# 2     Nuevo León, San Pedro Garza García  (81)8378-6238
# 3       Ciudad de México, Miguel Hidalgo  +525510163803
# 4       Ciudad de México, Miguel Hidalgo     5552573737
# ...                                  ...            ...
# 6122    Ciudad de México, Miguel Hidalgo     5526792674
# 6123         Baja California Sur, La Paz  +526122340454
# 6124                Jalisco, Guadalajara     3331058999
# 6125                     Yucatán, Mérida   +13026903002
# 6126                                 NaN  +529982141871
#
#                                               Sitio web
# 0     https://network-de-asesores-inmobiliarios.easy...
# 1                        https://www.inmuebleshahn.com/
# 2                                                   NaN
# 3                                                   NaN
# 4     https://m-y-m-consultores-inmobiliarios.easybr...
# ...                                                 ...
# 6122              https://altiusgroupmx.easybroker.com/
# 6123                                                NaN
# 6124                                                NaN
# 6125                                                NaN
# 6126                                                NaN
#
# [6127 rows x 4 columns]
